# %%
import pandas as pd
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# Load data
df = pd.read_csv('C:/Users/ASUS/DimasOktavianPrasetyo_22230016.csv')  # Pastikan path benar
tweets = df['Isi Tweet'].dropna().tolist()

# Preprocessing ringan + hapus stopword Indonesia
factory = StopWordRemoverFactory()
stop_words = set(factory.get_stop_words())

def preprocess(text):
    text = re.sub(r"http\S+", "", text)  # Hapus link
    text = re.sub(r"[^a-zA-Z\s]", "", text)  # Hapus simbol/karakter non-alfabet
    text = text.lower()
    tokens = text.split()
    return ' '.join([w for w in tokens if w not in stop_words])

# Preprocessing semua tweet
tweets_cleaned = [preprocess(t) for t in tweets]

# Vektorisasi TF-IDF
vectorizer = TfidfVectorizer(max_df=0.8, min_df=2)
X = vectorizer.fit_transform(tweets_cleaned)

# Clustering dengan KMeans
k = 5
model = KMeans(n_clusters=k, random_state=42)
model.fit(X)

# Tampilkan hasil
for i in range(k):
    print(f"\nCluster {i + 1}:")
    indices = [j for j, label in enumerate(model.labels_) if label == i]
    for idx in indices[:5]:  # Tampilkan 5 tweet pertama dari cluster ini
        print(f"- {tweets[idx]}")
# Out:
# Cluster 1:
# - 2. Geopolitik #1
# 🇨🇳 China vs 🇺🇸 Amerika: Perang dagang 2025 makin panas. AS kenakan tarif baharu ke atas cip &amp; bateri dari China. Dunia tengok… siapa yang akan ‘terbatuk’ dulu?
# - Perang Dagang Amerika vs China Makin Memanas dan Menggila, Indonesia bakal ikutan Perang ga ya?
# Simak Video berikut dan kunjungi link di Bio
# #Perang #dagang #Amerika #China #Indonesia #fyp #fypp #DISKOTIK[DiskusiSeputarPolitik] #21 https://t.co/oU7B5OO2Jy
# - @TxtdariHI Presiden nya :
# "Kita ini bangsa yang besar"
# Awokawokawok, kocak 😝
# Mana sok2an mau jadi mediator perang dagang China dan Amerika lagi, geli gk tuh 🤣
# - @tol_tul31434 @__Zhuxin China vs Amerika perang dagang... perang teknologi...pehhh negara kita emang parah SDM rendah..masih aja mikir hantu hantu..pohon gede angker lah apalah...tolol..udah tolol komen pede bgt lagi.. G malu lo bang??otak lo kerdil kah??kalau iya mending minum racun aja bng. bunuh diri
# - @FaktaBerita89 Kemarin kata nitizen Amerika bakalan hancur karena perang dagang China? Yang bego itu orang miskin atau orang kaya?
#
# Cluster 2:
# - RT @perupadata: Inikah gencatan senjata perang dagang Amerika dan China?
#
# Indonesia dan negara lain yang sempat dikenakan tarif tinggi gima…
# - RT @perupadata: Inikah gencatan senjata perang dagang Amerika dan China?
#
# Indonesia dan negara lain yang sempat dikenakan tarif tinggi gima…
# - RT @perupadata: Inikah gencatan senjata perang dagang Amerika dan China?
#
# Indonesia dan negara lain yang sempat dikenakan tarif tinggi gima…
# - RT @perupadata: Inikah gencatan senjata perang dagang Amerika dan China?
#
# Indonesia dan negara lain yang sempat dikenakan tarif tinggi gima…
